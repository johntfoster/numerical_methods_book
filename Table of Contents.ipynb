# %% [markdown]
# ## Numerical Methods
#
# ### Table of Contents
#
# #### [Chapter 1](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter1.ipynb?create=1)
#
#   1. Computer Preliminaries and Error Descriptors
#   1. The Numerical Analyst's Enemy:  Roundoff Error
#   1. Stability
#   1. Conventional Programming Structures
#
# #### [Chapter 2](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter2.ipynb?create=1)
#
#   1. Solving Systems of Linear Equations
#   1. Stability of Gaussian Elimination
#   1. Gauss-Jordan Elimination
#   1. Partial Pivoting
#   1. Matrix Inversion with Gauss-Jordan Scheme
#
# #### [Chapter 3](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter3.ipynb?create=1)
#
#   1. LU Factorization (LU Decomposition)
#   1. Doolittle Algorithm
#   1. Crout Algorithm
#   1. Cholesky Decomposition
#   1. Determinant of a Matrix
#
# #### [Chapter 4](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter4.ipynb?create=1)
#
#   1. Iterative Methods for Solving Linear Systems
#   1. Observations on the Jacobi Iterative Method
#   1. Convergence of Iterative Methods
#
# #### [Chapter 5](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter5.ipynb?create=1)
#
#   1. The Eigenvalue Problem
#   1. The Power Method
#   1. Inverse Power Method
#   1. Deflation Techniques
#
# #### [Chapter 6](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter6.ipynb?create=1)
#
#   1. Householder's Method
#   1. Gram-Schmidt Process
#   1. QR Factorization
#   1. QR Algorithm for Computing Eigenvalues
#
# #### [Chapter 7](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter7.ipynb?create=1)
#
#   1. Singular Value Decomposition
#   1. Survey of Software for use in Linear Algebra
#
# #### [Chapter 8](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter8.ipynb?create=1)
#
#   1. Nonlinear Root Finding - Bisection Method
#   1. Bisection Method
#   1. Newton-Raphson (Newton's Method)
#   1. Secant Method
#   1. Convergence and Other Comments
#   1. Hybrid Methods
#
# #### [Chapter 9](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter9.ipynb?create=1)
#
#   1. Roots of Polynomials
#   1. Synthetic Division
#   1. Horner's Method
#   1. Deflation
#   1. M$\ddot{\text{u}}$ller's Method
#
# #### [Chapter 10](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter10.ipynb?create=1)
#
#   1. Systems of Nonlinear Equations
#   1. Newton's Method for Systems with Nonlinear Equations
#   1. Quasi-Newton Methods
#   1. Broyden's Method
#   1. Sherman-Morrison Formula
#   1. Steepest Descent Techniques
#
# #### [Chapter 11](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter11.ipynb?create=1)
#
#   1. Numerical Differentiation
#   1. Divided-difference Polynomials
#   1. Newton-Gregory Interpolating Polynomial
#   1. Error of Polynomial Interpolation
#   1. Returning to Numerical Derivatives
#   1. Symbolic Operators
#   1. Formulas for Higher Derivatives
#
# #### [Chapter 12](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter12.ipynb?create=1)
#   1. Summary of Newton-Cotes formulas
#   1. Trapezoid Rule
#   1. Simpson's Rule
#   1. Gaussian Quadrature
#
# #### [Chapter 13](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter13.ipynb?create=1)
#   1. Numerical Solution of Ordinary Differential Equations
#   1. Taylor-Series Method
#   1. Euler Methods
#   1. Runge-Kutta Methods
#
# #### [Chapter 14](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter14.ipynb?create=1)
#   1. Multistep Methods
#   1. Milne's Method
#   1. Adams-Moulton Method
#
# #### [Chapter 15](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter15.ipynb?create=1)
#   1. Systems of Ordinary Differential Equations
#   1. Runge-Kutta-Fehlberg
#   1. Comparison of Methods for Numerically Solving Differential Equations
#   1. Explicit vs. Implicit Stability
#
# #### [Chapter 16](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter16.ipynb?create=1)
#   1. Boundary Value Problems
#   1. Shooting Method
#   1. Finite Difference Methods
#   1. Step Size and Accuracy
#   1. Non-linear Difference Equations
#   1. Derivative Boundary Conditions
#
# #### [Chapter 17](http://nbviewer.ipython.org/github/johntfoster/numerical_methods_book/blob/master/Chapter17.ipynb?create=1)
